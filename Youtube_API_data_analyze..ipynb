# %%
from googleapiclient.discovery import build

# %%
youTubeApiKey='AIzaSyAI7zHGUy0sj7yuGHX07N3Ighfm93jhVrM'
youtube=build('youtube','v3',developerKey=youTubeApiKey)
channelId='UCQRIKdVEcMTIBaoHLMEN5uA'

# %%
statdata=youtube.channels().list(part='statistics',id=channelId).execute()
stats=statdata['items'][0]['statistics']
stats
# Out:
# {'viewCount': '253349702',
#  'subscriberCount': '2240000',
#  'hiddenSubscriberCount': False,
#  'videoCount': '1857'}

# %%
videoCount=stats['videoCount']
videoCount
# Out:
# '1857'

# %%
viewCount=stats['viewCount']
viewCount
# Out:
# '253349702'

# %%
suscriberCount=stats['subscriberCount']
suscriberCount
# Out:
# '2240000'

# %%
snippetdata=youtube.channels().list(part='snippet',id=channelId).execute()
snippetdata
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'c56cOzGE2kDpJbgpvqvVWpx4l64',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'Xg7hnEVeIiyi-MAOtneOhfu1_0w',
#    'id': 'UCQRIKdVEcMTIBaoHLMEN5uA',
#    'snippet': {'title': 'Defence Squad',
# ...

# %%
title=snippetdata['items'][0]['snippet']['title']
title
# Out:
# 'Defence Squad'

# %%
description=snippetdata['items'][0]['snippet']['description']
description
# Out:
# 'हैलो डिफेंस लवर्स, आपका बहुत बहुत स्वागत है हमारे चैनल "Defence Squad" में, हमने यह चैनल हमारे उन सभी दोस्तों के लिए बनाया है जो इंडियन डिफेंस के बारे में अपनी भाषा में जानना चाहते है, "Defence Squad" चैनल में आपको रोज़ाना एक नयी वीडियो मिलेगी जहा हम कोशिश करेगें आपको  इंडियन डिफेंस की दुनिया के बारे में कुछ जरुरी बातें बताने की|\n.\nHello Defence Lovers, Welcome to "Defence Squad" - India’s first dedicated digital channel for Indian Armed Forces, We created this channel on 5 June 2017, our motive behind creating this channel was to make Easy to Understand, Indian Armed Forces Videos in Hindi, and We wanted each and every Individual whoever is interested in Indian Defence to be able to understand it in the easiest possible way. We here at \'Defence Squad\' are true patriots, doing this as our Hobby, We post a new video daily, on topics that create the most confusion, Please SUBSCRIBE to Defence Squad, Thanks. जय हिन्द, वन्दे मातरम|\n\nFor Business enquiries: DefenceXPNetwork@gmail.c
# ...

# %%
contentdata=youtube.channels().list(id=channelId,part='contentDetails').execute()
playlist_id = contentdata['items'][0]['contentDetails']['relatedPlaylists']['uploads']
videos = []
next_page_token = None

while 1:
    res = youtube.playlistItems().list(playlistId=playlist_id, 
                                    part='snippet', 
                                    maxResults=50,
                                    pageToken=next_page_token).execute()
    videos += res['items']
    next_page_token = res.get('nextPageToken')

    if next_page_token is None:
        break

print(videos)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
video_ids = list(map(lambda x:x['snippet']['resourceId']['videoId'], videos))
video_ids
# Out:
# ['0y5ImDEJBmA',
#  'Wp4cJxAw29c',
#  'haRNcF8jFEk',
#  'h_6Dqlvn1FU',
#  'LqmOfkuwcO4',
#  'GWAJ-_IXYv4',
#  '4L9W9NmicBI',
#  '7Z6p1R_T5Ac',
#  'j5DtUtLGeMk',
#  'VTPGOwtBJZk',
#  'bPpMOOCs76A',
#  '0uNd5G21bz0',
#  'bIstes_XiHY',
#  'vnDLWtAJ8UM',
#  '-6ing3XJuHU',
#  'TvulcglAfk8',
#  'm3Z66--MTqE',
#  'KWuGJiwVMH8',
#  'MbJXvILRt2Y',
#  'bdYPYZgVlcE',
#  'ijFiYsgvSY0',
#  'OzuQcaGZtXI',
#  '0yfwOl1iZfU',
#  'e4O52sa4imc',
#  'UQ3JowNuQx4',
#  'frCn8h_hSY0',
#  'fTUxBvsHBOw',
#  'ePXMCImd9g0',
#  'kGcRuZMwdNA',
#  'bTPYlSdwcg0',
#  'xRIkG9RzPUI',
#  'Vcte9u7f17c',
#  'JTedGpO0vqQ',
#  'mOMTSM9b-mQ',
#  'Y2i7Ey1J-XY',
#  'dp_wiZc2AUE',
#  'twNcNdIS4IM',
#  'jMC5c-4nUc8',
#  'V1vAeGkeu6M',
#  'Yreo5PxUbTI',
#  'as119jsZrts',
#  '4TrEa46ncLQ',
#  'j496KjoblPo',
#  'p27PZwaRnm8',
#  'snLu0yfbZFM',
#  'sVbPBKFjEEw',
#  'TJiVGUmDQmg',
#  '-rNryC6snho',
#  'kRkxfdXAY9Y',
#  'DHYEXDwAE7g',
#  'kQNs5OvSfI4',
#  'wmr0ZUofV6M',
#  'Z2ejZcCDCbY',
#  '8-d_3qAqA8Y',
#  'RP8ln_UEr3Y',
# ...

# %%
stats = []
for i in range(0, len(video_ids), 40):
    res = (youtube).videos().list(id=','.join(video_ids[i:i+40]),part='statistics').execute()
    stats += res['items']
print(stats)
# Out:
# [{'kind': 'youtube#video', 'etag': '5xwFAliDbyYcjxbcXdkGEsNVkmk', 'id': '0y5ImDEJBmA', 'statistics': {'viewCount': '65978', 'likeCount': '7333', 'dislikeCount': '89', 'favoriteCount': '0', 'commentCount': '313'}}, {'kind': 'youtube#video', 'etag': 'WGJH-mYntJ88BNYfwjY5nBSlOuQ', 'id': 'Wp4cJxAw29c', 'statistics': {'viewCount': '83140', 'likeCount': '8623', 'dislikeCount': '145', 'favoriteCount': '0', 'commentCount': '530'}}, {'kind': 'youtube#video', 'etag': 'w_udtFDPc7DB_efbzSDw4ljWKdc', 'id': 'haRNcF8jFEk', 'statistics': {'viewCount': '73195', 'likeCount': '7959', 'dislikeCount': '85', 'favoriteCount': '0', 'commentCount': '349'}}, {'kind': 'youtube#video', 'etag': 'kf_dvZiaFzj2x0gLxLNGAbH-MD0', 'id': 'h_6Dqlvn1FU', 'statistics': {'viewCount': '32847', 'likeCount': '4170', 'dislikeCount': '40', 'favoriteCount': '0', 'commentCount': '299'}}, {'kind': 'youtube#video', 'etag': '6jIv23XAC2BIxhKdzp6mdAJewLs', 'id': 'LqmOfkuwcO4', 'statistics': {'viewCount': '81906', 'likeCount': '8009', 
# ...

# %%
title=[]
liked=[]
disliked=[]
views=[]
url=[]
comment=[]
for i in range(len(videos)):      
        title.append((videos[i])['snippet']['title'])
        url.append("https://www.youtube.com/watch?v="+(videos[i])['snippet']['resourceId']['videoId'])
        liked.append(int((stats[i])['statistics']['likeCount']))
        disliked.append(int((stats[i])['statistics']['dislikeCount']))
        views.append(int((stats[i])['statistics']['viewCount']))
        comment.append(int((stats[i])['statistics']['commentCount']))

# %%
import pandas as pd
data={'title':title,'url':url,'liked':liked,'disliked':disliked,'views':views,'comment':comment}
df=pd.DataFrame(data)
df.head(10)
# Out:
#                                                title  \
# 0  Defence Updates #1239 - New Mango Anti-Tank Am...
# 1  Defence Updates #1238 - ₹15000 Crore For AMCA,...
# 2  Defence Updates #1237 - Army Recruitment Scam,...
# 3                      Top 5 Most Produced Guns Ever
# 4  Defence Updates #1236 - ISRO Sounding Rockets,...
# 5  Defence Updates #1235 - DRDO Exoskeleton, US T...
# 6  Defence Updates #1234 - DRDO Light Tank, Tejas...
# 7  Does India Have A Nuclear Button? India's Nucl...
# 8  Defence Updates #1233 - Military Drill In Spac...
# 9  Defence Updates #1232 - Indian Pilots MH-60R T...
#
#                                            url  liked  disliked   views  \
# 0  https://www.youtube.com/watch?v=0y5ImDEJBmA   7333        89   65978
# 1  https://www.youtube.com/watch?v=Wp4cJxAw29c   8623       145   83140
# 2  https://www.youtube.com/watch?v=haRNcF8jFEk   7959        85   73195
# 3  https://www.youtube.com/watch?v=h_6Dqlvn1FU   4170        40   32847
# ...

# %% [raw]
# #Least Views

# %%
top10=df.head(10)
ax=top10.plot.bar(x='title',y='views',figsize=(12,8),fontsize=14)

# %%
bottom10=df.tail(10)
ax=bottom10.plot.bar(x='title',y='views',figsize=(12,8),fontsize=12)

# %% [raw]
# #like vs dislikes videos

# %%
#Top 10 Videos_avg
liked_avg = top10['liked'].mean()
disliked_avg = top10['disliked'].mean()
comment_avg = top10['comment'].mean()
print('top 10')
print("average liked",liked_avg)
print("average disliked",disliked_avg)
print("average comment",comment_avg)
# Out:
# top 10
# average liked 7735.6
# average disliked 101.6
# average comment 374.7

# %%
#Bottom10 videos_avg
liked_avg = bottom10['liked'].mean()
disliked_avg = bottom10['disliked'].mean()
comment_avg = bottom10['comment'].mean()
print('bottom 10')
print("average liked",liked_avg)
print("average disliked",disliked_avg)
print("average comment",comment_avg)
# Out:
# bottom 10
# average liked 8664.3
# average disliked 491.9
# average comment 611.2

# %%
df.describe()
# Out:
#                liked      disliked         views       comment
# count    1857.000000   1857.000000  1.857000e+03   1857.000000
# mean     6564.404416    178.129779  1.364808e+05    390.981691
# std      7455.933813    506.138783  3.488320e+05    876.586687
# min        47.000000      0.000000  1.396000e+03      1.000000
# 25%      2347.000000     42.000000  4.095800e+04    122.000000
# 50%      4757.000000     93.000000  7.012300e+04    252.000000
# 75%      8516.000000    166.000000  1.147320e+05    455.000000
# max    103656.000000  17669.000000  1.051474e+07  32608.000000

# %%
df.to_csv('Defence_squad.csv')
