# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Dropout rate dataset.csv")
df.head(10)
# Out:
#   Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0       1              A & N Islands                 0.68
# 1       2             Andhra Pradesh                 3.18
# 2       3          Arunachal Pradesh                15.16
# 3       4                      Assam                 6.24
# 4       5                      Bihar                  NaN
# 5       6                 Chandigarh                  NaN
# 6       7                Chhatisgarh                 4.14
# 7       8       Dadra & Nagar Haveli                  NaN
# 8       9                Daman & Diu                  NaN
# 9      10                      Delhi                  NaN
#
#    Primary - 2014-2015  Primary - 2014-2015.1  Upper Primary - 2012-2013  \
# 0                 1.21                   0.51                       1.23
# 1                 4.35                   6.72                       3.36
# 2                10.89                  10.82                       7.47
# ...

# %%
df.columns
# Out:
# Index(['Sl. No.', 'Level of Education - State', 'Primary - 2012-2013',
#        'Primary - 2014-2015', 'Primary - 2014-2015.1',
#        'Upper Primary - 2012-2013', 'Upper Primary - 2013-2014',
#        'Upper Primary - 2014-2015', 'Secondary - 2012-2013',
#        'Secondary - 2013-2014', 'Secondary - 2014-2015',
#        'Senior Secondary - 2012-2013', 'Senior Secondary - 2013-2014',
#        'Senior Secondary - 2014-2015'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Primary - 2012-2013  Primary - 2014-2015  Primary - 2014-2015.1  \
# count            29.000000            33.000000              31.000000
# mean              5.354138             4.919394               4.480323
# std               5.095706             4.990541               3.767533
# min               0.340000             0.200000               0.370000
# 25%               1.990000             1.210000               1.375000
# 50%               4.060000             3.070000               3.050000
# 75%               7.070000             7.080000               6.655000
# max              24.110000            19.410000              15.360000
#
#        Upper Primary - 2012-2013  Upper Primary - 2013-2014  \
# count                  31.000000                  35.000000
# mean                    4.277742                   4.284571
# std                     3.876914                   3.386170
# min                     0.100000                   0.510000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sl. No.                       37 non-null     object
#  1   Level of Education - State    37 non-null     object
#  2   Primary - 2012-2013           29 non-null     float64
#  3   Primary - 2014-2015           33 non-null     float64
#  4   Primary - 2014-2015.1         31 non-null     float64
#  5   Upper Primary - 2012-2013     31 non-null     float64
#  6   Upper Primary - 2013-2014     35 non-null     float64
#  7   Upper Primary - 2014-2015     35 non-null     float64
#  8   Secondary - 2012-2013         34 non-null     float64
#  9   Secondary - 2013-2014         36 non-null     float64
#  10  Secondary - 2014-2015         36 non-null     float64
#  11  Senior Secondary - 2012-2013  24 non-null     float64
# ...

# %% [raw]
# Data Cleansing and Preparation

# %%
df_null=df.isna().mean().round(4) * 100
df_null
# Out:
# Sl. No.                          0.00
# Level of Education - State       0.00
# Primary - 2012-2013             21.62
# Primary - 2014-2015             10.81
# Primary - 2014-2015.1           16.22
# Upper Primary - 2012-2013       16.22
# Upper Primary - 2013-2014        5.41
# Upper Primary - 2014-2015        5.41
# Secondary - 2012-2013            8.11
# Secondary - 2013-2014            2.70
# Secondary - 2014-2015            2.70
# Senior Secondary - 2012-2013    35.14
# Senior Secondary - 2013-2014    27.03
# Senior Secondary - 2014-2015    24.32
# dtype: float64

# %%
mean=df.mean()
mean
# Out:
# Primary - 2012-2013              5.354138
# Primary - 2014-2015              4.919394
# Primary - 2014-2015.1            4.480323
# Upper Primary - 2012-2013        4.277742
# Upper Primary - 2013-2014        4.284571
# Upper Primary - 2014-2015        3.992571
# Secondary - 2012-2013           16.602353
# Secondary - 2013-2014           18.240556
# Secondary - 2014-2015           17.294806
# Senior Secondary - 2012-2013     7.839583
# Senior Secondary - 2013-2014     8.573333
# Senior Secondary - 2014-2015     8.420714
# dtype: float64

# %%
df.count()
# Out:
# Sl. No.                         37
# Level of Education - State      37
# Primary - 2012-2013             29
# Primary - 2014-2015             33
# Primary - 2014-2015.1           31
# Upper Primary - 2012-2013       31
# Upper Primary - 2013-2014       35
# Upper Primary - 2014-2015       35
# Secondary - 2012-2013           34
# Secondary - 2013-2014           36
# Secondary - 2014-2015           36
# Senior Secondary - 2012-2013    24
# Senior Secondary - 2013-2014    27
# Senior Secondary - 2014-2015    28
# dtype: int64

# %%
df.sort_index()
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
#Here replace all "NAN" value with MEAN 
df.fillna(mean)
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands             0.680000
# 1           2             Andhra Pradesh             3.180000
# 2           3          Arunachal Pradesh            15.160000
# 3           4                      Assam             6.240000
# 4           5                      Bihar             5.354138
# 5           6                 Chandigarh             5.354138
# 6           7                Chhatisgarh             4.140000
# 7           8       Dadra & Nagar Haveli             5.354138
# 8           9                Daman & Diu             5.354138
# 9          10                      Delhi             5.354138
# 10         11                        Goa             5.354138
# 11         12                    Gujarat             0.740000
# 12         13                    Haryana             1.290000
# 13         14           Himachal Pradesh             0.450000
# ...

# %% [raw]
# Data Visualization and Insights Extraction

# %%
df.plot.hist()

# %%
plt.rcParams['figure.figsize'] = [11.5,8]
df.plot(kind='barh',stacked=True, colormap = 'Set1')
plt.title("Avg.% Growth of States for Duration 2013-14, 2014-15", fontweight = 'bold')
plt.xlabel("Avg. % Growth", fontweight = 'bold')
plt.ylabel("Level of Education - State", fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Level of Education - State')

# %%
plt.rcParams['figure.figsize'] = [11.5,8]
mean.plot(kind='barh',stacked=True, colormap = 'Set1')
plt.title("Avg.% Growth of States for Duration 2013-14, 2014-15 ", fontweight = 'bold')
plt.xlabel("Avg. % Growth", fontweight = 'bold')
plt.ylabel("Level of Education - State", fontweight = 'bold')
# Out:
# Text(0, 0.5, 'Level of Education - State')

# %%
#Selecting the GSDP for year 2014-2015

df_total_gdp = df.iloc[2:,4:5]

# %%
df.plot.scatter(x='Level of Education - State',y='Senior Secondary - 2014-2015')
